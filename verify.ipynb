# %% [markdown]
# ## This notebook provides an environment and example of verifying the computation of M_l,k (in particular M_5,4)
#
# Use `M_lk(x, l, k)` to compute the bounds of finite Mina Margin Map[l,k] evaluated
# at x up the precision of 12 decimal places. Include the argument `True` to print
# the intermediate values of the computation.
#
# Use `M_lk_down(a, b, l, k)` to compute the lower bounds of finite Mina Margin
# Map[l,k] evaluated within the interval [a, b] up the precision of 12 decimal
# places. Similarly, include the argument `True` to print the intermediate values
# of the computation.

# %%
from functions import *

# Set decimal precision to 12
iv.dps = 12

x, l, k = iv.mpf('0.58'), 5, 4
M_lk(x, l, k, True)
# Out:
# s_0 = [0.57999999999992724, 0.58000000000004093]
# d_0 = [1.0700124764650809, 1.0700124764659904]
# s_0 = [0.57999999999992724, 0.58000000000004093]
# d_0 = [1.0700124764650809, 1.0700124764659904]
# s_1 = [0.050407725234656198, 0.050407725234741463]
# d_1 = [1.0019497200764818, 1.0019497200776186]
# s_0 = [0.57999999999992724, 0.58000000000004093]
# d_0 = [1.0700124764650809, 1.0700124764659904]
# s_1 = [0.050407725234656198, 0.050407725234741463]
# d_1 = [1.0019497200764818, 1.0019497200776186]
# s_2 = [0.0010408203735754462, 0.0010408203735838839]
# d_2 = [1.0000010765834304, 1.0000010765845673]
# s_0 = [0.57999999999992724, 0.58000000000004093]
# d_0 = [1.0700124764650809, 1.0700124764659904]
# s_1 = [0.050407725234656198, 0.050407725234741463]
# d_1 = [1.0019497200764818, 1.0019497200776186]
# s_2 = [0.0010408203735754462, 0.0010408203735838839]
# d_2 = [1.0000010765834304, 1.0000010765845673]
# s_3 = [5.391301492442763e-7, 5.3913014936267118e-7]
# ...

# %%
a, b, l, k = iv.mpf('0.58'), iv.mpf('0.580000001'), 5, 4
M_lk_down(a, b, l, k, True)
# Out:
# s_0 = [0.57999999999992724, 0.58000000000004093]
# d_0 = [1.0700124764650809, 1.0700124764659904]
# s_0 = [0.57999999999992724, 0.58000000000004093]
# d_0 = [1.0700124764650809, 1.0700124764659904]
# s_1 = [0.050407725234656198, 0.050407725234741463]
# d_1 = [1.0019497200764818, 1.0019497200776186]
# s_0 = [0.57999999999992724, 0.58000000000004093]
# d_0 = [1.0700124764650809, 1.0700124764659904]
# s_1 = [0.050407725234656198, 0.050407725234741463]
# d_1 = [1.0019497200764818, 1.0019497200776186]
# s_2 = [0.0010408203735754462, 0.0010408203735838839]
# d_2 = [1.0000010765834304, 1.0000010765845673]
# s_0 = [0.57999999999992724, 0.58000000000004093]
# d_0 = [1.0700124764650809, 1.0700124764659904]
# s_1 = [0.050407725234656198, 0.050407725234741463]
# d_1 = [1.0019497200764818, 1.0019497200776186]
# s_2 = [0.0010408203735754462, 0.0010408203735838839]
# d_2 = [1.0000010765834304, 1.0000010765845673]
# s_3 = [5.391301492442763e-7, 5.3913014936267118e-7]
# ...
